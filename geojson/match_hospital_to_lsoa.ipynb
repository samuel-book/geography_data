# %% [markdown]
# # Match hospitals to LSOAs
#
# Find which LSOA contains each hospital.
#
# Use geojson files for the LSOAs. Match the coordinates of each LSOA shape with the coordinates of each hospital. Find the shape that contains the point.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# For importing geojson:
import json

# For creating new points:
# from geojson import Feature, Point #FeatureCollection
from shapely.geometry import shape, Point

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Hospital locations

# %%
# df_hospitals = pd.read_csv('../data/stroke_hospitals_2022.csv')
df_hospitals = pd.read_csv('../data_tabular/stroke_teams_postcodes.csv')

df_hospitals.head()
# Out:
#                           stroke_team Postcode  Grid Reference  Easting  \
# 0  Queen Elizabeth Hospital Edgbaston   B152TH  SP 04427 83926   404427
# 1          Sandwell District Hospital   B714HJ  SP 00919 92165   400919
# 2          Royal United Hospital Bath   BA13NG  ST 72922 66042   372922
# 3            Yeovil District Hospital  BA214AT  ST 55562 16398   355562
# 4            Royal Blackburn Hospital   BB23HH  SD 69305 26794   369305
#
#    Northing        lat      long
# 0    283926  52.453272 -1.936284
# 1    292165  52.527357 -1.987884
# 2    166042  51.392764 -2.390566
# 3    116398  50.945297 -2.633907
# 4    426794  53.736622 -2.466806

# %%
hospital_points = []

for r in range(df_hospitals.shape[0]):
    # Get longitude and latitude from the dataframe
    # and convert it into a "Point" that the shape package can understand
    # and later compare with polygons of LSOA coordinates.
    long = df_hospitals['long'].iloc[r]
    lat = df_hospitals['lat'].iloc[r]
    point = Point(long, lat)

    hospital_points.append(point)

# %%
hospital_points
# Out:
# [<POINT (-1.936 52.453)>,
#  <POINT (-1.988 52.527)>,
#  <POINT (-2.391 51.393)>,
#  <POINT (-2.634 50.945)>,
#  <POINT (-2.467 53.737)>,
#  <POINT (-1.795 53.806)>,
#  <POINT (-2.255 53.601)>,
#  <POINT (-0.364 50.817)>,
#  <POINT (0.271 50.787)>,
#  <POINT (-0.118 50.819)>,
#  <POINT (0.06 51.366)>,
#  <POINT (-2.593 51.497)>,
#  <POINT (-2.596 51.459)>,
#  <POINT (-2.971 51.322)>,
#  <POINT (-2.955 54.896)>,
#  <POINT (0.139 52.174)>,
#  <POINT (-3.189 51.507)>,
#  <POINT (-3.572 51.518)>,
#  <POINT (-3.386 51.764)>,
#  <POINT (-2.899 53.212)>,
#  <POINT (-3.095 53.371)>,
#  <POINT (0.465 51.775)>,
#  <POINT (0.086 51.771)>,
#  <POINT (0.899 51.91)>,
#  <POINT (1.087 51.267)>,
#  <POINT (1.389 51.378)>,
#  <POINT (-1.444 52.421)>,
#  <POINT (-1.583 52.29)>,
#  <POINT (-2.476 53.118)>,
#  <POINT (0.258 51.435)>,
#  <POINT (-1.513 52.912)>,
#  <POINT (-1.593 54.789)>,
#  <POINT (-0.667 53.587)>,
#  <POINT (-1.109 53.531)>,
#  <POINT (-2.447 50.713)>,
#  <POINT (-2.118 52.502)>,
#  <POINT (-1.821 50.747)>,
#  <POINT (-0.058 51.519)>,
#  <POINT (-3.507 50.717)>,
#  <POINT (-4.051 51.092)>,
#  <POINT (-3.016 53.821)>,
#  <POINT (-2.234 51.866)>,
#  <POINT (-0.742 51.32)>,
#  <POINT (-0.322 51.575)>,
#  <POINT (-0.753 51.626)>,
#  <POINT (-2.706 52.057)>,
#  <POINT (-0.358 53.744)>,
#  <POINT (-1.857 53.705)>,
#  <POINT (0.709 52.232)>,
#  <POINT (1.196 52.06)>,
#  <POINT (-0.527 51.377)>,
#  <POINT (-0.273 51.325)>,
#  <POINT (-2.786 53.421)>,
#  <POINT (-2.965 53.41)>,
#  <POINT (-2.935 53.468)>,
#  <POINT (-3.208 54.136)>,
#  <POINT (-2.799 54.043)>,
#  <POINT (-1.135 52.628)>,
#  <POINT (-3.01 53.046)>,
#  <POINT (-3.496 53.272)>,
#  <POINT (-4.16 53.209)>,
#  <POINT (-0.518 53.232)>,
#  <POINT (-1.552 53.801)>,
#  <POINT (-0.474 51.894)>,
#  <POINT (-2.323 53.487)>,
#  <POINT (0.484 51.274)>,
#  <POINT (0.542 51.378)>,
#  <POINT (-0.736 52.026)>,
#  <POINT (-1.618 54.98)>,
#  <POINT (-1.569 55.074)>,
#  <POINT (-1.238 53.135)>,
#  <POINT (-1.186 52.943)>,
#  <POINT (-0.887 52.237)>,
#  <POINT (-2.996 51.646)>,
#  <POINT (1.718 52.562)>,
#  <POINT (1.221 52.618)>,
#  <POINT (-0.137 51.525)>,
#  <POINT (-1.22 51.764)>,
#  <POINT (0.447 52.757)>,
#  <POINT (-0.28 52.585)>,
#  <POINT (-4.114 50.417)>,
#  <POINT (-0.768 50.844)>,
#  <POINT (-1.301 50.711)>,
#  <POINT (-1.071 50.85)>,
#  <POINT (-2.707 53.791)>,
#  <POINT (-0.959 51.451)>,
#  <POINT (-0.161 51.219)>,
#  <POINT (-0.091 50.991)>,
#  <POINT (0.179 51.569)>,
#  <POINT (-1.493 53.378)>,
#  <POINT (-1.4 53.236)>,
#  <POINT (-4.136 51.692)>,
#  <POINT (-4.285 51.868)>,
#  <POINT (-4.965 51.813)>,
#  <POINT (-3.935 51.685)>,
#  <POINT (-0.093 51.47)>,
#  <POINT (-0.213 51.925)>,
#  <POINT (-2.132 53.384)>,
#  <POINT (-1.728 51.538)>,
#  <POINT (-1.435 50.933)>,
#  <POINT (-1.331 51.061)>,
#  <POINT (-1.79 51.044)>,
#  <POINT (-1.411 54.903)>,
#  <POINT (0.689 51.554)>,
#  <POINT (0.451 51.558)>,
#  <POINT (-2.215 53.004)>,
#  <POINT (-0.176 51.427)>,
#  <POINT (-0.213 51.474)>,
#  <POINT (-4.072 52.416)>,
#  <POINT (-3.12 51.012)>,
#  <POINT (-2.511 52.712)>,
#  <POINT (0.916 51.141)>,
#  <POINT (-3.554 50.482)>,
#  <POINT (-5.095 50.268)>,
#  <POINT (-1.347 54.583)>,
#  <POINT (-1.214 54.552)>,
#  <POINT (-0.404 51.649)>,
#  <POINT (-1.488 53.693)>,
#  <POINT (-2.181 52.191)>,
#  <POINT (-2.096 52.598)>,
#  <POINT (-1.084 53.971)>]

# %% [markdown]
# ### Geojson containing all LSOAs:

# %%
# with open('./LSOA_2011.geojson') as f:
with open('../data_geojson/ons_data/LSOA_(Dec_2011)_Boundaries_Super_Generalised_Clipped_(BSC)_EW_V3.geojson') as f:
    geojson_ew = json.load(f)

# %%
# Fill these lists with the LSOAs containing the hospitals:
hospital_LSOA11CD = []
hospital_LSOA11NM = []
hospital_LSOA11NMW = []

for point in hospital_points:
    # Check each LSOA in turn to see if it contains this point.
    i = 0
    while i < len(geojson_ew['features']):
        # Get the coordinates and other info for this LSOA:
        feature = geojson_ew['features'][i]
        # Turn this into a shape:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            # Save LSOA details to list:
            hospital_LSOA11CD.append(feature['properties']['LSOA11CD'])
            hospital_LSOA11NM.append(feature['properties']['LSOA11NM'])
            hospital_LSOA11NMW.append(feature['properties']['LSOA11NMW'])
            # Update the iterator so that the loop breaks:
            i = len(geojson_ew['features'])
        # Update the iterator for another go round the loop:
        i += 1

# %% [markdown]
# ## Link the LSOAs with other regions
#
# Import the big file we made earlier:

# %%
df_regions = pd.read_csv('../data_tabular/LSOA_regions.csv')

df_regions.head()
# Out:
#     LSOA11CD   LSOA11NM  LSOA11LONG  LSOA11LAT    CCG19CD  \
# 0  E01031349  Adur 001A    -0.22737   50.83651  E38000213
# 1  E01031350  Adur 001B    -0.22842   50.84244  E38000213
# 2  E01031351  Adur 001C    -0.25300   50.85845  E38000213
# 3  E01031352  Adur 001D    -0.23812   50.84290  E38000213
# 4  E01031370  Adur 001E    -0.24649   50.83958  E38000213
#
#                        CCG19NM    STP19CD                 STP19NM LHB20CD  \
# 0  NHS Coastal West Sussex CCG  E54000033  Sussex and East Surrey     NaN
# 1  NHS Coastal West Sussex CCG  E54000033  Sussex and East Surrey     NaN
# 2  NHS Coastal West Sussex CCG  E54000033  Sussex and East Surrey     NaN
# 3  NHS Coastal West Sussex CCG  E54000033  Sussex and East Surrey     NaN
# 4  NHS Coastal West Sussex CCG  E54000033  Sussex and East Surrey     NaN
#
#   LHB20NM LHB20NMW    LAD17CD LAD17NM    SCN17CD           SCN17NM    RGN11CD  \
# 0     NaN      NaN  E07000223    Adur  E55000010  South East Coast  E12000008
# 1     NaN      NaN  E07000223    Adur  E55000010  South East Coast  E12000008
# 2     NaN      NaN  E07000223    Adur  E55000010  South East Coast  E12000008
# 3     NaN      NaN  E07000223    Adur  E55000010  South East Coast  E12000008
# 4     NaN      NaN  E07000223    Adur  E55000010  South East Coast  E12000008
#
#       RGN11NM
# 0  South East
# 1  South East
# 2  South East
# 3  South East
# 4  South East

# %%
all_regions = []

for LSOA in hospital_LSOA11CD:
    # Get region information for this hospital:
    regions_here = df_regions[df_regions['LSOA11CD'] == LSOA].values
    # Keep a copy of everything except the first two columns
    # (LSOA11 codes and names), which we already have ready:
    all_regions.append(regions_here[0][2:])

all_regions = np.array(all_regions, dtype=object)
all_regions
# Out:
# array([[-1.94449, 52.45242, 'E38000220', ..., 'West Midlands',
#         'E12000005', 'West Midlands'],
#        [-1.98593, 52.5221, 'E38000144', ..., 'West Midlands',
#         'E12000005', 'West Midlands'],
#        [-2.38922, 51.39029, 'E38000009', ..., 'South West', 'E12000009',
#         'South West'],
#        ...,
#        [-2.19107, 52.18789, 'E38000166', ..., 'West Midlands',
#         'E12000005', 'West Midlands'],
#        [-2.09493, 52.59789, 'E38000210', ..., 'West Midlands',
#         'E12000005', 'West Midlands'],
#        [-1.08157, 53.97053, 'E38000188', ..., 'Yorkshire and The Humber',
#         'E12000003', 'Yorkshire and The Humber']], dtype=object)

# %% [markdown]
# ## Create a dataframe to save

# %%
# Gather the hospital names, locations, and containing LSOAs...
table = np.stack([
    df_hospitals['Postcode'],
    df_hospitals['stroke_team'],#['Stroke Team'],
    df_hospitals['long'],
    df_hospitals['lat'],
    hospital_LSOA11CD,
    hospital_LSOA11NM,
    hospital_LSOA11NMW,
    ], axis=-1)

# ... and then add the other region information from the file.
table = np.concatenate([table, all_regions], axis=1)

# %%
df_hospitals_and_lsoas = pd.DataFrame(
    table,
    columns=[
        'Postcode',
        'Stroke Team',
        'long',
        'lat',
        'LSOA11CD',
        'LSOA11NM',
        'LSOA11NMW',
        *df_regions.columns[2:]
    ]
)

df_hospitals_and_lsoas.head()
# Out:
#   Postcode                         Stroke Team      long        lat  \
# 0   B152TH  Queen Elizabeth Hospital Edgbaston -1.936284  52.453272
# 1   B714HJ          Sandwell District Hospital -1.987884  52.527357
# 2   BA13NG          Royal United Hospital Bath -2.390566  51.392764
# 3  BA214AT            Yeovil District Hospital -2.633907  50.945297
# 4   BB23HH            Royal Blackburn Hospital -2.466806  53.736622
#
#     LSOA11CD                           LSOA11NM  \
# 0  E01033562                    Birmingham 087F
# 1  E01010104                      Sandwell 017E
# 2  E01014428  Bath and North East Somerset 008B
# 3  E01029231                South Somerset 014A
# 4  E01012632         Blackburn with Darwen 011F
#
#                            LSOA11NMW LSOA11LONG LSOA11LAT    CCG19CD  ...  \
# 0                    Birmingham 087F   -1.94449  52.45242  E38000220  ...
# 1                      Sandwell 017E   -1.98593   52.5221  E38000144  ...
# 2  Bath and North East Somerset 008B   -2.38922  51.39029  E38000009  ...
# 3                South Somerset 014A    -2.6334  50.95035  E38000150  ...
# 4         Blackburn with Darwen 011F   -2.45667  53.73091  E38000014  ...
#
#                                              STP19NM LHB20CD LHB20NM LHB20NMW  \
# 0                            Birmingham and Solihull     NaN     NaN      NaN
# 1              The Black Country and West Birmingham     NaN     NaN      NaN
# 2  Bath and North East Somerset, Swindon and Wilt...     NaN     NaN      NaN
# 3                                           Somerset     NaN     NaN      NaN
# 4             Healthier Lancashire and South Cumbria     NaN     NaN      NaN
#
#      LAD17CD                       LAD17NM    SCN17CD  \
# 0  E08000025                    Birmingham  E55000008
# 1  E08000028                      Sandwell  E55000008
# 2  E06000022  Bath and North East Somerset  E55000009
# 3  E07000189                South Somerset  E55000009
# 4  E06000008         Blackburn with Darwen  E55000003
#
#                                             SCN17NM    RGN11CD        RGN11NM
# 0                                     West Midlands  E12000005  West Midlands
# 1                                     West Midlands  E12000005  West Midlands
# 2                                        South West  E12000009     South West
# 3                                        South West  E12000009     South West
# 4  Greater Manchester, Lancashire and South Cumbria  E12000002     North West
#
# [5 rows x 22 columns]

# %% [markdown]
# Save this dataframe to file:

# %%
df_hospitals_and_lsoas.to_csv('../data_tabular/hospitals_and_lsoas_descriptive_stats.csv', index=False)
