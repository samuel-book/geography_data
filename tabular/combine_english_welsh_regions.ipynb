# %% [markdown]
# # Combine English and Welsh region lists
#
# ## Notebook setup:

# %%
import pandas as pd

# %% [markdown]
# ## Import English regions and LSOAs

# %%
df_eng = pd.read_csv('../data_tabular/ons_data/LSOA11_LOC22_ICB22_LAD22_EN_LU.csv')

# %%
# Reduce the columns:
df_eng = df_eng[[
    'LSOA11CD',
    'LSOA11NM',
    'LOC22CD',
    'LOC22NM',
    'ICB22CD',
    'ICB22NM',
]]

# %%
df_eng.head()
# Out:
#     LSOA11CD     LSOA11NM    LOC22CD                                LOC22NM  \
# 0  E01012367  Halton 007A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 1  E01012368  Halton 003A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 2  E01012369  Halton 005A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 3  E01012370  Halton 007B  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 4  E01012371  Halton 016A  E38000068  NHS Cheshire and Merseyside ICB - 01F
#
#      ICB22CD                                            ICB22NM
# 0  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 1  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 2  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 3  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 4  E54000008  NHS Cheshire and Merseyside Integrated Care Board

# %% [markdown]
# ## Import Welsh regions and LSOAs

# %%
df_wal_oa = pd.read_csv('../data_tabular/ons_data/Output_Areas_(2011)_to_Local_Health_Boards_(December_2020)_Lookup_in_Wales.csv')
df_wal_lsoa = pd.read_csv('../data_tabular/ons_data/Output_Area_to_LSOA_to_MSOA_to_Local_Authority_District_(December_2017)_Lookup_with_Area_Classifications_in_Great_Britain.csv')

# %%
df_wal_oa.columns
# Out:
# Index(['FID', 'OA11CD', 'LHB20CD', 'LHB20NM', 'LHB20NMW'], dtype='object')

# %%
df_wal_lsoa.columns
# Out:
# Index(['OA11CD', 'OAC11CD', 'OAC11NM', 'LSOA11CD', 'LSOA11NM', 'SOAC11CD',
#        'SOAC11NM', 'MSOA11CD', 'MSOA11NM', 'LAD17CD', 'LAD17NM', 'LACCD',
#        'LACNM', 'RGN11CD', 'RGN11NM', 'CTRY11CD', 'CTRY11NM', 'FID'],
#       dtype='object')

# %%
df_wal = pd.merge(
    df_wal_lsoa[['OA11CD', 'LSOA11CD', 'LSOA11NM', ]],
    df_wal_oa[['OA11CD', 'LHB20CD', 'LHB20NM', 'LHB20NMW']],
    left_on='OA11CD', right_on='OA11CD', how='right'
)
# Drop the OA column:
df_wal = df_wal.drop('OA11CD', axis='columns')
# Drop duplicates:
df_wal = df_wal.drop_duplicates()

# %%
df_wal
# Out:
#        LSOA11CD               LSOA11NM    LHB20CD  \
# 0     W01000012  Isle of Anglesey 006B  W11000023
# 1     W01000021  Isle of Anglesey 002C  W11000023
# 9     W01000022  Isle of Anglesey 004A  W11000023
# 10    W01000013  Isle of Anglesey 005B  W11000023
# 20    W01000023  Isle of Anglesey 007D  W11000023
# ...         ...                    ...        ...
# 9889  W01001865           Cardiff 022C  W11000029
# 9890  W01001890           Cardiff 021D  W11000029
# 9927  W01001893           Cardiff 010B  W11000029
# 9938  W01001892           Cardiff 020D  W11000029
# 9956  W01001867           Cardiff 016B  W11000029
#
#                                        LHB20NM  \
# 0      Betsi Cadwaladr University Health Board
# 1      Betsi Cadwaladr University Health Board
# 9      Betsi Cadwaladr University Health Board
# 10     Betsi Cadwaladr University Health Board
# 20     Betsi Cadwaladr University Health Board
# ...                                        ...
# 9889  Cardiff and Vale University Health Board
# 9890  Cardiff and Vale University Health Board
# 9927  Cardiff and Vale University Health Board
# 9938  Cardiff and Vale University Health Board
# 9956  Cardiff and Vale University Health Board
#
#                                      LHB20NMW
# 0      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 1      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 9      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 10     Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 20     Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# ...                                       ...
# 9889  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9890  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9927  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9938  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9956  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
#
# [1909 rows x 5 columns]

# %% [markdown]
# ## Combine England and Wales

# %%
# Set both to have a shared axis type:
df_eng = df_eng.set_index(['LSOA11NM', 'LSOA11CD'])
df_wal = df_wal.set_index(['LSOA11NM', 'LSOA11CD'])

# %%
df_combo = pd.concat((df_eng, df_wal), axis='columns')
df_combo = df_combo.reset_index()

# %%
df_combo
# Out:
#            LSOA11NM   LSOA11CD    LOC22CD  \
# 0       Halton 007A  E01012367  E38000068
# 1       Halton 003A  E01012368  E38000068
# 2       Halton 005A  E01012369  E38000068
# 3       Halton 007B  E01012370  E38000068
# 4       Halton 016A  E01012371  E38000068
# ...             ...        ...        ...
# 34748  Cardiff 022C  W01001865        NaN
# 34749  Cardiff 021D  W01001890        NaN
# 34750  Cardiff 010B  W01001893        NaN
# 34751  Cardiff 020D  W01001892        NaN
# 34752  Cardiff 016B  W01001867        NaN
#
#                                      LOC22NM    ICB22CD  \
# 0      NHS Cheshire and Merseyside ICB - 01F  E54000008
# 1      NHS Cheshire and Merseyside ICB - 01F  E54000008
# 2      NHS Cheshire and Merseyside ICB - 01F  E54000008
# 3      NHS Cheshire and Merseyside ICB - 01F  E54000008
# 4      NHS Cheshire and Merseyside ICB - 01F  E54000008
# ...                                      ...        ...
# 34748                                    NaN        NaN
# 34749                                    NaN        NaN
# 34750                                    NaN        NaN
# 34751                                    NaN        NaN
# 34752                                    NaN        NaN
#
#                                                  ICB22NM    LHB20CD  \
# 0      NHS Cheshire and Merseyside Integrated Care Board        NaN
# 1      NHS Cheshire and Merseyside Integrated Care Board        NaN
# 2      NHS Cheshire and Merseyside Integrated Care Board        NaN
# 3      NHS Cheshire and Merseyside Integrated Care Board        NaN
# 4      NHS Cheshire and Merseyside Integrated Care Board        NaN
# ...                                                  ...        ...
# 34748                                                NaN  W11000029
# 34749                                                NaN  W11000029
# 34750                                                NaN  W11000029
# 34751                                                NaN  W11000029
# 34752                                                NaN  W11000029
#
#                                         LHB20NM  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 34748  Cardiff and Vale University Health Board
# 34749  Cardiff and Vale University Health Board
# 34750  Cardiff and Vale University Health Board
# 34751  Cardiff and Vale University Health Board
# 34752  Cardiff and Vale University Health Board
#
#                                       LHB20NMW
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 34748  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 34749  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 34750  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 34751  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 34752  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
#
# [34753 rows x 9 columns]

# %% [markdown]
# ## Merge in ISDNs
#
# From a file made in another notebook:

# %%
df_sicbl_to_icb_to_isdn = pd.read_csv('../data_tabular/SICBL_ICB_ISDN.csv')

# %%
df_sicbl_to_icb_to_isdn.head()
# Out:
#      LOC22CD LOC22CDH                             LOC22NM    ICB22CD ICB22CDH  \
# 0  E38000240      93C  NHS North Central London ICB - 93C  E54000028      QMJ
# 1  E38000255    A3A8R   NHS North East London ICB - A3A8R  E54000029      QMF
# 2  E38000256    W2U3Z   NHS North West London ICB - W2U3Z  E54000027      QRV
# 3  E38000244      72Q     NHS South East London ICB - 72Q  E54000030      QKK
# 4  E38000245      36L     NHS South West London ICB - 36L  E54000031      QWE
#
#                                           ICB22NM  NHSER22CD NHSER22CDH  \
# 0  NHS North Central London Integrated Care Board  E40000003        Y56
# 1     NHS North East London Integrated Care Board  E40000003        Y56
# 2     NHS North West London Integrated Care Board  E40000003        Y56
# 3     NHS South East London Integrated Care Board  E40000003        Y56
# 4     NHS South West London Integrated Care Board  E40000003        Y56
#
#   NHSER22NM    ISDN
# 0    London  London
# 1    London  London
# 2    London  London
# 3    London  London
# 4    London  London

# %%
df_combo = pd.merge(
    df_combo, df_sicbl_to_icb_to_isdn[['LOC22NM', 'ISDN']],
    left_on='LOC22NM', right_on='LOC22NM', how='left'
)

# %%
df_combo.to_csv('../data_tabular/regions_lsoa_ew.csv', index=False)

# %% [markdown]
# ## Drop the LSOA

# %%
df_combo_small = df_combo_small.drop(['LSOA11NM', 'LSOA11CD'], axis='columns')
df_combo_small = df_combo_small.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 df_combo_small = df_combo.reset_index()
# ----> 2 df_combo_small = df_combo_small.drop(['LSOA11NM', 'LSOA11CD'], axis='columns')
#       3 df_combo_small = df_combo_small.drop_duplicates()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['LSOA11NM', 'LSOA11CD'] not found in axis"

# %%
df_combo_small

# %%
df_combo.to_csv('../data_tabular/regions_ew.csv', index=False)
