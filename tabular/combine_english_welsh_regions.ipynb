# %% [markdown]
# # Combine English and Welsh region lists
#
# ## Notebook setup:

# %%
import pandas as pd

# %% [markdown]
# ## Import English regions and LSOAs

# %%
df_eng = pd.read_csv('../data_tabular/ons_data/LSOA11_LOC22_ICB22_LAD22_EN_LU.csv')

# %%
# Reduce the columns:
df_eng = df_eng[[
    'LSOA11CD',
    'LSOA11NM',
    'LOC22CD',
    'LOC22NM',
    'ICB22CD',
    'ICB22NM',
]]

# %%
df_eng.head()
# Out:
#     LSOA11CD     LSOA11NM    LOC22CD                                LOC22NM  \
# 0  E01012367  Halton 007A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 1  E01012368  Halton 003A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 2  E01012369  Halton 005A  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 3  E01012370  Halton 007B  E38000068  NHS Cheshire and Merseyside ICB - 01F
# 4  E01012371  Halton 016A  E38000068  NHS Cheshire and Merseyside ICB - 01F
#
#      ICB22CD                                            ICB22NM
# 0  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 1  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 2  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 3  E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 4  E54000008  NHS Cheshire and Merseyside Integrated Care Board

# %% [markdown]
# ## Import Welsh regions and LSOAs

# %%
df_wal_oa = pd.read_csv('../data_tabular/ons_data/Output_Areas_(2011)_to_Local_Health_Boards_(December_2020)_Lookup_in_Wales.csv')
df_wal_lsoa = pd.read_csv('../data_tabular/ons_data/Output_Area_to_LSOA_to_MSOA_to_Local_Authority_District_(December_2017)_Lookup_with_Area_Classifications_in_Great_Britain.csv')

# %%
df_wal_oa.columns
# Out:
# Index(['FID', 'OA11CD', 'LHB20CD', 'LHB20NM', 'LHB20NMW'], dtype='object')

# %%
df_wal_lsoa.columns
# Out:
# Index(['OA11CD', 'OAC11CD', 'OAC11NM', 'LSOA11CD', 'LSOA11NM', 'SOAC11CD',
#        'SOAC11NM', 'MSOA11CD', 'MSOA11NM', 'LAD17CD', 'LAD17NM', 'LACCD',
#        'LACNM', 'RGN11CD', 'RGN11NM', 'CTRY11CD', 'CTRY11NM', 'FID'],
#       dtype='object')

# %%
df_wal = pd.merge(
    df_wal_lsoa[['OA11CD', 'LSOA11CD', 'LSOA11NM', ]],
    df_wal_oa[['OA11CD', 'LHB20CD', 'LHB20NM', 'LHB20NMW']],
    left_on='OA11CD', right_on='OA11CD', how='right'
)
# Drop the OA column:
df_wal = df_wal.drop('OA11CD', axis='columns')
# Drop duplicates:
df_wal = df_wal.drop_duplicates()

# %%
df_wal
# Out:
#        LSOA11CD               LSOA11NM    LHB20CD  \
# 0     W01000012  Isle of Anglesey 006B  W11000023
# 1     W01000021  Isle of Anglesey 002C  W11000023
# 9     W01000022  Isle of Anglesey 004A  W11000023
# 10    W01000013  Isle of Anglesey 005B  W11000023
# 20    W01000023  Isle of Anglesey 007D  W11000023
# ...         ...                    ...        ...
# 9889  W01001865           Cardiff 022C  W11000029
# 9890  W01001890           Cardiff 021D  W11000029
# 9927  W01001893           Cardiff 010B  W11000029
# 9938  W01001892           Cardiff 020D  W11000029
# 9956  W01001867           Cardiff 016B  W11000029
#
#                                        LHB20NM  \
# 0      Betsi Cadwaladr University Health Board
# 1      Betsi Cadwaladr University Health Board
# 9      Betsi Cadwaladr University Health Board
# 10     Betsi Cadwaladr University Health Board
# 20     Betsi Cadwaladr University Health Board
# ...                                        ...
# 9889  Cardiff and Vale University Health Board
# 9890  Cardiff and Vale University Health Board
# 9927  Cardiff and Vale University Health Board
# 9938  Cardiff and Vale University Health Board
# 9956  Cardiff and Vale University Health Board
#
#                                      LHB20NMW
# 0      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 1      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 9      Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 10     Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# 20     Bwrdd Iechyd Prifysgol Betsi Cadwaladr
# ...                                       ...
# 9889  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9890  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9927  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9938  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# 9956  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
#
# [1909 rows x 5 columns]

# %% [markdown]
# ## Combine England and Wales

# %%
# Set both to have a shared axis type:
df_eng = df_eng.set_index(['LSOA11NM', 'LSOA11CD'])
df_wal = df_wal.set_index(['LSOA11NM', 'LSOA11CD'])

# %%
df_combo = pd.concat((df_eng, df_wal), axis='columns')

# %%
df_combo
# Out:
#                           LOC22CD                                LOC22NM  \
# LSOA11NM     LSOA11CD
# Halton 007A  E01012367  E38000068  NHS Cheshire and Merseyside ICB - 01F
# Halton 003A  E01012368  E38000068  NHS Cheshire and Merseyside ICB - 01F
# Halton 005A  E01012369  E38000068  NHS Cheshire and Merseyside ICB - 01F
# Halton 007B  E01012370  E38000068  NHS Cheshire and Merseyside ICB - 01F
# Halton 016A  E01012371  E38000068  NHS Cheshire and Merseyside ICB - 01F
# ...                           ...                                    ...
# Cardiff 022C W01001865        NaN                                    NaN
# Cardiff 021D W01001890        NaN                                    NaN
# Cardiff 010B W01001893        NaN                                    NaN
# Cardiff 020D W01001892        NaN                                    NaN
# Cardiff 016B W01001867        NaN                                    NaN
#
#                           ICB22CD  \
# LSOA11NM     LSOA11CD
# Halton 007A  E01012367  E54000008
# Halton 003A  E01012368  E54000008
# Halton 005A  E01012369  E54000008
# Halton 007B  E01012370  E54000008
# Halton 016A  E01012371  E54000008
# ...                           ...
# Cardiff 022C W01001865        NaN
# Cardiff 021D W01001890        NaN
# Cardiff 010B W01001893        NaN
# Cardiff 020D W01001892        NaN
# Cardiff 016B W01001867        NaN
#
#                                                                   ICB22NM  \
# LSOA11NM     LSOA11CD
# Halton 007A  E01012367  NHS Cheshire and Merseyside Integrated Care Board
# Halton 003A  E01012368  NHS Cheshire and Merseyside Integrated Care Board
# Halton 005A  E01012369  NHS Cheshire and Merseyside Integrated Care Board
# Halton 007B  E01012370  NHS Cheshire and Merseyside Integrated Care Board
# Halton 016A  E01012371  NHS Cheshire and Merseyside Integrated Care Board
# ...                                                                   ...
# Cardiff 022C W01001865                                                NaN
# Cardiff 021D W01001890                                                NaN
# Cardiff 010B W01001893                                                NaN
# Cardiff 020D W01001892                                                NaN
# Cardiff 016B W01001867                                                NaN
#
#                           LHB20CD                                   LHB20NM  \
# LSOA11NM     LSOA11CD
# Halton 007A  E01012367        NaN                                       NaN
# Halton 003A  E01012368        NaN                                       NaN
# Halton 005A  E01012369        NaN                                       NaN
# Halton 007B  E01012370        NaN                                       NaN
# Halton 016A  E01012371        NaN                                       NaN
# ...                           ...                                       ...
# Cardiff 022C W01001865  W11000029  Cardiff and Vale University Health Board
# Cardiff 021D W01001890  W11000029  Cardiff and Vale University Health Board
# Cardiff 010B W01001893  W11000029  Cardiff and Vale University Health Board
# Cardiff 020D W01001892  W11000029  Cardiff and Vale University Health Board
# Cardiff 016B W01001867  W11000029  Cardiff and Vale University Health Board
#
#                                                        LHB20NMW
# LSOA11NM     LSOA11CD
# Halton 007A  E01012367                                      NaN
# Halton 003A  E01012368                                      NaN
# Halton 005A  E01012369                                      NaN
# Halton 007B  E01012370                                      NaN
# Halton 016A  E01012371                                      NaN
# ...                                                         ...
# Cardiff 022C W01001865  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# Cardiff 021D W01001890  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# Cardiff 010B W01001893  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# Cardiff 020D W01001892  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
# Cardiff 016B W01001867  Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
#
# [34753 rows x 7 columns]

# %%
df_combo.to_csv('../data_tabular/regions_lsoa_ew.csv', index=False)

# %% [markdown]
# ## Drop the LSOA

# %%
df_combo_small = df_combo.reset_index()
df_combo_small = df_combo_small.drop(['LSOA11NM', 'LSOA11CD'], axis='columns')
df_combo_small = df_combo_small.drop_duplicates()

# %%
df_combo_small
# Out:
#          LOC22CD                                LOC22NM    ICB22CD  \
# 0      E38000068  NHS Cheshire and Merseyside ICB - 01F  E54000008
# 79     E38000194  NHS Cheshire and Merseyside ICB - 02E  E54000008
# 206    E38000233  NHS Cheshire and Merseyside ICB - 27D  E54000008
# 652    E38000091  NHS Cheshire and Merseyside ICB - 01J  E54000008
# 750    E38000101  NHS Cheshire and Merseyside ICB - 99A  E54000008
# ...          ...                                    ...        ...
# 33293        NaN                                    NaN        NaN
# 33565        NaN                                    NaN        NaN
# 33799        NaN                                    NaN        NaN
# 34046        NaN                                    NaN        NaN
# 34446        NaN                                    NaN        NaN
#
#                                                  ICB22NM    LHB20CD  \
# 0      NHS Cheshire and Merseyside Integrated Care Board        NaN
# 79     NHS Cheshire and Merseyside Integrated Care Board        NaN
# 206    NHS Cheshire and Merseyside Integrated Care Board        NaN
# 652    NHS Cheshire and Merseyside Integrated Care Board        NaN
# 750    NHS Cheshire and Merseyside Integrated Care Board        NaN
# ...                                                  ...        ...
# 33293                                                NaN  W11000025
# 33565                                                NaN  W11000031
# 33799                                                NaN  W11000030
# 34046                                                NaN  W11000028
# 34446                                                NaN  W11000029
#
#                                          LHB20NM  \
# 0                                            NaN
# 79                                           NaN
# 206                                          NaN
# 652                                          NaN
# 750                                          NaN
# ...                                          ...
# 33293          Hywel Dda University Health Board
# 33565        Swansea Bay University Health Board
# 33799  Cwm Taf Morgannwg University Health Board
# 34046      Aneurin Bevan University Health Board
# 34446   Cardiff and Vale University Health Board
#
#                                        LHB20NMW
# 0                                           NaN
# 79                                          NaN
# 206                                         NaN
# 652                                         NaN
# 750                                         NaN
# ...                                         ...
# 33293          Bwrdd Iechyd Prifysgol Hywel Dda
# 33565       Bwrdd Iechyd Prifysgol Bae Abertawe
# 33799  Bwrdd Iechyd Prifysgol Cwm Taf Morgannwg
# 34046      Bwrdd Iechyd Prifysgol Aneurin Bevan
# 34446   Bwrdd Iechyd Prifysgol Caerdydd a’r Fro
#
# [113 rows x 7 columns]

# %%
df_combo.to_csv('../data_tabular/regions_ew.csv', index=False)
