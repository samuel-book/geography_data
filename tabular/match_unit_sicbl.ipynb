# %% [markdown]
# # Match stroke units with the Sub Integrated Care Board Location containing them
#
# Find which Sub Integrated Care Board Location (SICBL) contains each stroke unit.
#
# Take the existing list of stroke units and the LSOAs containing them, and match the LSOAs to SICBLs.
#
# ## Notebook setup:

# %%
import pandas as pd

# %% [markdown]
# ## Import stroke unit to LSOA data:

# %%
df_units = pd.read_csv('../data_tabular/stroke_hospitals_2022_regions.csv', index_col=0)

# %%
# Reduce the columns:
df_units = df_units[[
    'Postcode',
    'Hospital_name',
    'Use_IVT',
    'Use_MT',
    'Use_MSU',
    'LSOA11NM',
    'LHB20NM',
    'LHB20NMW'
]]

# %%
df_units.head()
# Out:
#   Postcode Hospital_name  Use_IVT  Use_MT  Use_MSU  \
# 0   RM70AG        RM70AG        1       1        1
# 1    E11BB         E11BB        1       1        1
# 2   SW66SX        SW66SX        1       1        1
# 3   SE59RW        SE59RW        1       1        1
# 4   BR68ND        BR68ND        1       0        0
#
#                       LSOA11NM LHB20NM LHB20NMW
# 0                Havering 017C     NaN      NaN
# 1           Tower Hamlets 017A     NaN      NaN
# 2  Hammersmith and Fulham 022C     NaN      NaN
# 3                 Lambeth 014C     NaN      NaN
# 4                 Bromley 036C     NaN      NaN

# %% [markdown]
# ## Import LSOA to SICBL data

# %%
df_regions = pd.read_csv('../data_tabular/ons_data/LSOA11_LOC22_ICB22_LAD22_EN_LU.csv')

# %%
# Reduce the columns:
df_regions = df_regions[[
    'LSOA11NM',
    'LOC22NM',
    'ICB22NM'
]]

# %%
df_regions.head()
# Out:
#       LSOA11NM                                LOC22NM  \
# 0  Halton 007A  NHS Cheshire and Merseyside ICB - 01F
# 1  Halton 003A  NHS Cheshire and Merseyside ICB - 01F
# 2  Halton 005A  NHS Cheshire and Merseyside ICB - 01F
# 3  Halton 007B  NHS Cheshire and Merseyside ICB - 01F
# 4  Halton 016A  NHS Cheshire and Merseyside ICB - 01F
#
#                                              ICB22NM
# 0  NHS Cheshire and Merseyside Integrated Care Board
# 1  NHS Cheshire and Merseyside Integrated Care Board
# 2  NHS Cheshire and Merseyside Integrated Care Board
# 3  NHS Cheshire and Merseyside Integrated Care Board
# 4  NHS Cheshire and Merseyside Integrated Care Board

# %% [markdown]
# ## Merge the two

# %%
df_combo = pd.merge(
    df_units, df_regions,
    left_on='LSOA11NM', right_on='LSOA11NM',
    how='left'
)

# %%
df_combo
# Out:
#     Postcode Hospital_name  Use_IVT  Use_MT  Use_MSU  \
# 0     RM70AG        RM70AG        1       1        1
# 1      E11BB         E11BB        1       1        1
# 2     SW66SX        SW66SX        1       1        1
# 3     SE59RW        SE59RW        1       1        1
# 4     BR68ND        BR68ND        1       0        0
# ..       ...           ...      ...     ...      ...
# 136  SA148QF      SA14 8QF        1       0        0
# 137  SA312AF      SA31 2AF        1       0        0
# 138  SA612PZ      SA61 2PZ        1       0        0
# 139   SA66NL       SA6 6NL        1       0        0
# 140  NP202UB      NP20 2UB        0       0        0
#
#                         LSOA11NM                              LHB20NM  \
# 0                  Havering 017C                                  NaN
# 1             Tower Hamlets 017A                                  NaN
# 2    Hammersmith and Fulham 022C                                  NaN
# 3                   Lambeth 014C                                  NaN
# 4                   Bromley 036C                                  NaN
# ..                           ...                                  ...
# 136         Carmarthenshire 020B    Hywel Dda University Health Board
# 137         Carmarthenshire 007D    Hywel Dda University Health Board
# 138           Pembrokeshire 005D    Hywel Dda University Health Board
# 139                 Swansea 003F  Swansea Bay University Health Board
# 140                          NaN                                  NaN
#
#                                 LHB20NMW                            LOC22NM  \
# 0                                    NaN  NHS North East London ICB - A3A8R
# 1                                    NaN  NHS North East London ICB - A3A8R
# 2                                    NaN  NHS North West London ICB - W2U3Z
# 3                                    NaN    NHS South East London ICB - 72Q
# 4                                    NaN    NHS South East London ICB - 72Q
# ..                                   ...                                ...
# 136     Bwrdd Iechyd Prifysgol Hywel Dda                                NaN
# 137     Bwrdd Iechyd Prifysgol Hywel Dda                                NaN
# 138     Bwrdd Iechyd Prifysgol Hywel Dda                                NaN
# 139  Bwrdd Iechyd Prifysgol Bae Abertawe                                NaN
# 140                                  NaN                                NaN
#
#                                          ICB22NM
# 0    NHS North East London Integrated Care Board
# 1    NHS North East London Integrated Care Board
# 2    NHS North West London Integrated Care Board
# 3    NHS South East London Integrated Care Board
# 4    NHS South East London Integrated Care Board
# ..                                           ...
# 136                                          NaN
# 137                                          NaN
# 138                                          NaN
# 139                                          NaN
# 140                                          NaN
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Merge in ISDNs
#
# From a file made in another notebook:

# %%
df_sicbl_to_icb_to_isdn = pd.read_csv('../data_tabular/SICBL_ICB_ISDN.csv')

# %%
df_sicbl_to_icb_to_isdn.head()
# Out:
#      LOC22CD LOC22CDH                             LOC22NM    ICB22CD ICB22CDH  \
# 0  E38000240      93C  NHS North Central London ICB - 93C  E54000028      QMJ
# 1  E38000255    A3A8R   NHS North East London ICB - A3A8R  E54000029      QMF
# 2  E38000256    W2U3Z   NHS North West London ICB - W2U3Z  E54000027      QRV
# 3  E38000244      72Q     NHS South East London ICB - 72Q  E54000030      QKK
# 4  E38000245      36L     NHS South West London ICB - 36L  E54000031      QWE
#
#                                           ICB22NM  NHSER22CD NHSER22CDH  \
# 0  NHS North Central London Integrated Care Board  E40000003        Y56
# 1     NHS North East London Integrated Care Board  E40000003        Y56
# 2     NHS North West London Integrated Care Board  E40000003        Y56
# 3     NHS South East London Integrated Care Board  E40000003        Y56
# 4     NHS South West London Integrated Care Board  E40000003        Y56
#
#   NHSER22NM    ISDN
# 0    London  London
# 1    London  London
# 2    London  London
# 3    London  London
# 4    London  London

# %%
df_combo = pd.merge(
    df_combo, df_sicbl_to_icb_to_isdn[['LOC22NM', 'ISDN']],
    left_on='LOC22NM', right_on='LOC22NM', how='left'
)

# %%
df_combo.to_csv('../data_tabular/stroke_units_regions.csv', index=False)
